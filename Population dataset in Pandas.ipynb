# %%
import pandas as pd

# %%
data = pd.read_csv('population.csv')
data
# Out:
#     Rank                        State             Capital    Population  \
# 0      1                Uttar Pradesh             Lucknow  19,98,12,341
# 1      2                  Maharashtra              Mumbai  11,23,74,333
# 2      3                        Bihar               Patna  10,40,99,452
# 3      4                  West Bengal             Kolkata   9,12,76,115
# 4      5               Andhra Pradesh           Hyderabad   8,45,80,777
# 5      6               Madhya Pradesh              Bhopal   7,26,26,809
# 6      7                   Tamil Nadu             Chennai   7,21,47,030
# 7      8                    Rajasthan              Jaipur   6,85,48,437
# 8      9                    Karnataka           Bengaluru   6,10,95,297
# 9     10                      Gujarat         Gandhinagar   6,04,39,692
# 10    11                       Odisha        Bhubaneshwar   4,19,74,218
# 11    12                       Kerala  Thiruvananthapuram   3,34,06,061
# ...

# %%
data[['Rank','State']]
# Out:
#     Rank                        State
# 0      1                Uttar Pradesh
# 1      2                  Maharashtra
# 2      3                        Bihar
# 3      4                  West Bengal
# 4      5               Andhra Pradesh
# 5      6               Madhya Pradesh
# 6      7                   Tamil Nadu
# 7      8                    Rajasthan
# 8      9                    Karnataka
# 9     10                      Gujarat
# 10    11                       Odisha
# 11    12                       Kerala
# 12    13                    Jharkhand
# 13    14                        Assam
# 14    15                       Punjab
# 15    16                 Chhattisgarh
# 16    17                      Haryana
# 17    18                        Delhi
# 18    19            Jammu and Kashmir
# 19    20                  Uttarakhand
# 20    21             Himachal Pradesh
# 21    22                      Tripura
# 22    23                    Meghalaya
# 23    24                      Manipur
# ...

# %%
data[['State','Population']]
# Out:
#                           State    Population
# 0                 Uttar Pradesh  19,98,12,341
# 1                   Maharashtra  11,23,74,333
# 2                         Bihar  10,40,99,452
# 3                   West Bengal   9,12,76,115
# 4                Andhra Pradesh   8,45,80,777
# 5                Madhya Pradesh   7,26,26,809
# 6                    Tamil Nadu   7,21,47,030
# 7                     Rajasthan   6,85,48,437
# 8                     Karnataka   6,10,95,297
# 9                       Gujarat   6,04,39,692
# 10                       Odisha   4,19,74,218
# 11                       Kerala   3,34,06,061
# 12                    Jharkhand   3,29,88,134
# 13                        Assam   3,12,05,576
# 14                       Punjab   2,77,43,338
# 15                 Chhattisgarh   2,55,45,198
# 16                      Haryana   2,53,51,462
# 17                        Delhi   1,67,87,941
# 18            Jammu and Kashmir   1,25,41,302
# ...

# %%
data[['State','Rural Population']]
# Out:
#                           State Rural Population
# 0                 Uttar Pradesh     15,51,11,022
# 1                   Maharashtra      6,15,45,441
# 2                         Bihar      9,20,75,028
# 3                   West Bengal      6,22,13,676
# 4                Andhra Pradesh      5,63,61,702
# 5                Madhya Pradesh      5,25,37,899
# 6                    Tamil Nadu      3,71,89,229
# 7                     Rajasthan      5,15,40,236
# 8                     Karnataka      3,75,52,529
# 9                       Gujarat      3,46,70,817
# 10                       Odisha      3,49,51,234
# 11                       Kerala      1,74,45,506
# 12                    Jharkhand      2,50,36,946
# 13                        Assam      2,67,80,526
# 14                       Punjab      1,73,16,800
# 15                 Chhattisgarh      1,96,03,658
# 16                      Haryana      1,65,31,493
# 17                        Delhi         9,44,727
# ...

# %%
#loc = index name
data.loc[data.State=='Goa']
# Out:
#     Rank State Capital Population  % of Total Population     Males   Females  \
# 25    26   Goa  Panaji  14,58,545                   0.12  7,39,140  7,19,405
#
#    Gender Ratio  Literacy Rate (%) Rural Population Urban Population  \
# 25          973               88.7         5,51,414         9,06,309
#
#    Area (km*km) Density (1/km*km) Decadal Growth (%)
# 25        3,702               394              8.20%

# %%
data.loc[data.State=='Maharashtra']
# Out:
#    Rank        State Capital    Population  % of Total Population  \
# 1     2  Maharashtra  Mumbai  11,23,74,333                   9.28
#
#          Males      Females Gender Ratio  Literacy Rate (%) Rural Population  \
# 1  5,82,43,056  5,41,31,277          929              82.34      6,15,45,441
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# 1      5,08,27,531     3,07,713               365             16.00%

# %%
data.loc[data.Capital=='Jaipur']
# Out:
#    Rank      State Capital   Population  % of Total Population        Males  \
# 7     8  Rajasthan  Jaipur  6,85,48,437                   5.66  3,55,50,997
#
#        Females Gender Ratio  Literacy Rate (%) Rural Population  \
# 7  3,29,97,440          928              66.11      5,15,40,236
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# 7      1,70,80,776     3,42,239               201             21.40%

# %%
data.loc[data.Rank==5]
# Out:
#    Rank           State    Capital   Population  % of Total Population  \
# 4     5  Andhra Pradesh  Hyderabad  8,45,80,777                   6.99
#
#          Males      Females Gender Ratio  Literacy Rate (%) Rural Population  \
# 4  4,24,42,146  4,21,38,631          993              67.02      5,63,61,702
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# 4      2,82,19,075     2,75,045               308             10.98%

# %%
data['Population'] = data['Population'].astype(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     int64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     int64
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(6), object(6)
# ...

# %%
data['Population'] = data['Population'].str.replace(',','')

# %%
data['Population'] = pd.to_numeric(data['Population'])

# %%
data.loc[(data.State=='Tamil Nadu') & (data.Population>=500000)]
# Out:
#    Rank       State  Capital  Population  % of Total Population        Males  \
# 6     7  Tamil Nadu  Chennai    72147030                   5.96  3,61,37,975
#
#        Females Gender Ratio  Literacy Rate (%) Rural Population  \
# 6  3,60,09,055          996              80.09      3,71,89,229
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# 6      3,49,49,729     1,30,058               555             15.60%

# %%
data['Males'] = data['Males'].str.replace(',','')

# %%
data['Males'] = pd.to_numeric(data['Males'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     object
#  7   Gender Ratio           35 non-null     object
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(3), object(9)
# ...

# %%
data.loc[(data.Males>30966657)]
# Out:
#    Rank           State      Capital  Population  % of Total Population  \
# 0     1   Uttar Pradesh      Lucknow   199812341                  16.50
# 1     2     Maharashtra       Mumbai   112374333                   9.28
# 2     3           Bihar        Patna   104099452                   8.60
# 3     4     West Bengal      Kolkata    91276115                   7.54
# 4     5  Andhra Pradesh    Hyderabad    84580777                   6.99
# 5     6  Madhya Pradesh       Bhopal    72626809                   6.00
# 6     7      Tamil Nadu      Chennai    72147030                   5.96
# 7     8       Rajasthan       Jaipur    68548437                   5.66
# 9    10         Gujarat  Gandhinagar    60439692                   4.99
#
#        Males   Females  Gender Ratio  Literacy Rate (%)  Rural Population  \
# 0  104480510  95331831           912              67.68         155111022
# 1   58243056  54131277           929              82.34          61545441
# ...

# %%
data['Females'] = data['Females'].str.replace(',','')

# %%
data['Females'] = pd.to_numeric(data['Females'])

# %%
data.loc[(data['Females']>177710)]
# Out:
#     Rank              State             Capital  Population  \
# 0      1      Uttar Pradesh             Lucknow   199812341
# 1      2        Maharashtra              Mumbai   112374333
# 2      3              Bihar               Patna   104099452
# 3      4        West Bengal             Kolkata    91276115
# 4      5     Andhra Pradesh           Hyderabad    84580777
# 5      6     Madhya Pradesh              Bhopal    72626809
# 6      7         Tamil Nadu             Chennai    72147030
# 7      8          Rajasthan              Jaipur    68548437
# 8      9          Karnataka           Bengaluru    61095297
# 9     10            Gujarat         Gandhinagar    60439692
# 10    11             Odisha        Bhubaneshwar    41974218
# 11    12             Kerala  Thiruvananthapuram    33406061
# 12    13          Jharkhand              Ranchi    32988134
# 13    14              Assam              Dispur    31205576
# 14    15             Punjab          Chandigarh    27743338
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     object
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(4), object(8)
# ...

# %%
data['Gender Ratio'] = data['Gender Ratio'].str.replace(',','')
data['Gender Ratio'] = pd.to_numeric(data['Gender Ratio'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     int64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(5), object(7)
# ...

# %%
data['Rural Population'] = data['Rural Population'].str.replace(',','')
data['Rural Population'] = pd.to_numeric(data['Rural Population'])

# %%
data.loc[(data['Rural Population']>=56361702)]
# Out:
#    Rank           State    Capital  Population  % of Total Population  \
# 0     1   Uttar Pradesh    Lucknow   199812341                  16.50
# 1     2     Maharashtra     Mumbai   112374333                   9.28
# 2     3           Bihar      Patna   104099452                   8.60
# 3     4     West Bengal    Kolkata    91276115                   7.54
# 4     5  Andhra Pradesh  Hyderabad    84580777                   6.99
#
#        Males   Females  Gender Ratio  Literacy Rate (%)  Rural Population  \
# 0  104480510  95331831           912              67.68         155111022
# 1   58243056  54131277           929              82.34          61545441
# 2   54278157  49821295           918              61.80          92075028
# 3   46809027  44467088           950              76.26          62213676
# 4   42442146  42138631           993              67.02          56361702
#
#   Urban Population Area (km*km) Density (1/km*km) Decadal Growth (%)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     int64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     int64
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(6), object(6)
# ...

# %%
data['Urban Population'] = data['Urban Population'].str.replace(',','')
data['Urban Population']= pd.to_numeric(data['Urban Population'])
# Out:
#   Cell In[55], line 3
#     data.loc[(data.'Urban Population'>=15932171)]
#                    ^
# SyntaxError: invalid syntax

# %%
data.loc[(data['Urban Population']>=25712811)]
# Out:
#    Rank           State      Capital  Population  % of Total Population  \
# 0     1   Uttar Pradesh      Lucknow   199812341                  16.50
# 1     2     Maharashtra       Mumbai   112374333                   9.28
# 3     4     West Bengal      Kolkata    91276115                   7.54
# 4     5  Andhra Pradesh    Hyderabad    84580777                   6.99
# 6     7      Tamil Nadu      Chennai    72147030                   5.96
# 9    10         Gujarat  Gandhinagar    60439692                   4.99
#
#        Males   Females  Gender Ratio  Literacy Rate (%)  Rural Population  \
# 0  104480510  95331831           912              67.68         155111022
# 1   58243056  54131277           929              82.34          61545441
# 3   46809027  44467088           950              76.26          62213676
# 4   42442146  42138631           993              67.02          56361702
# 6   36137975  36009055           996              80.09          37189229
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     int64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     int64
#  10  Urban Population       35 non-null     int64
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(7), object(5)
# ...

# %%
data['Area (km*km)'] = data['Area (km*km)'].str.replace(',','')
data['Area (km*km)'] = pd.to_numeric(data['Area (km*km)'])

# %%
data.loc[(data['Area (km*km)']>=196024)]
# Out:
#     Rank              State            Capital  Population  \
# 0      1      Uttar Pradesh            Lucknow   199812341
# 1      2        Maharashtra             Mumbai   112374333
# 4      5     Andhra Pradesh          Hyderabad    84580777
# 5      6     Madhya Pradesh             Bhopal    72626809
# 7      8          Rajasthan             Jaipur    68548437
# 9     10            Gujarat        Gandhinagar    60439692
# 18    19  Jammu and Kashmir  Jammu and Kashmir    12541302
#
#     % of Total Population      Males   Females  Gender Ratio  \
# 0                   16.50  104480510  95331831           912
# 1                    9.28   58243056  54131277           929
# 4                    6.99   42442146  42138631           993
# 5                    6.00   37612306  35014503           931
# 7                    5.66   35550997  32997440           928
# 9                    4.99   31491260  28948432           919
# 18                   1.04    6640662   5900640           889
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     int64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     int64
#  10  Urban Population       35 non-null     int64
#  11  Area (km*km)           35 non-null     int64
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(8), object(4)
# ...

# %%
data['Density (1/km*km)'] = data['Density (1/km*km)'].str.replace(',','')
data['Density (1/km*km)'] = pd.to_numeric(data['Density (1/km*km)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 data['Density (1/km*km)'] = data['Density (1/km*km)'].str.replace(',','')
#       2 data['Density (1/km*km)'] = pd.to_numeric(data['Density (1/km*km)'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
data.loc[(data['Density (1/km*km)']>308)]
# Out:
#     Rank                   State             Capital  Population  \
# 0      1           Uttar Pradesh             Lucknow   199812341
# 1      2             Maharashtra              Mumbai   112374333
# 2      3                   Bihar               Patna   104099452
# 3      4             West Bengal             Kolkata    91276115
# 6      7              Tamil Nadu             Chennai    72147030
# 8      9               Karnataka           Bengaluru    61095297
# 11    12                  Kerala  Thiruvananthapuram    33406061
# 12    13               Jharkhand              Ranchi    32988134
# 13    14                   Assam              Dispur    31205576
# 14    15                  Punjab          Chandigarh    27743338
# 16    17                 Haryana          Chandigarh    25351462
# 17    18                   Delhi               Delhi    16787941
# 21    22                 Tripura            Agartala     3673917
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                35 non-null     object
#  3   Population             35 non-null     int64
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     int64
#  6   Females                35 non-null     int64
#  7   Gender Ratio           35 non-null     int64
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     int64
#  10  Urban Population       35 non-null     int64
#  11  Area (km*km)           35 non-null     int64
#  12  Density (1/km*km)      35 non-null     int64
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(9), object(3)
# ...

# %%
# data['Decadal Growth (%)'] = data['Decadal Growth (%)'].str.replace('%','')
# data['Decadal Growth (%)'] = pd.to_numeric(data['Decadal Growth (%)'])
data['Decadal Growth (%)'] = data['Decadal Growth (%)'].astype(float)

# %%
data.loc[(data['Decadal Growth (%)']>=25.10)]
# Out:
#     Rank                   State      Capital  Population  \
# 2      3                   Bihar        Patna   104099452
# 22    23               Meghalaya     Shillong     2966889
# 26    27       Arunachal Pradesh     Itanagar     1383727
# 27    28              Puducherry  Pondicherry     1247953
# 32    33  Dadra and Nagar Haveli     Silvassa      343709
# 33    34           Daman and Diu        Daman      243247
#
#     % of Total Population     Males   Females  Gender Ratio  \
# 2                    8.60  54278157  49821295           918
# 22                   0.25   1491832   1475057           989
# 26                   0.11    713912    669815           938
# 27                   0.10    612511    635442          1037
# 32                   0.03    193760    149949           774
# 33                   0.02    150301     92946           618
#
#     Literacy Rate (%)  Rural Population  Urban Population  Area (km*km)  \
# ...
